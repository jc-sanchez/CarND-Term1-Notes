# %%
import tensorflow as tf

# %% [markdown]
# # Intro
# We can do better if we already know something about our image.  If it has structure, and the network doesn't have to learn the structure from scratch, it will perform better.  An example is when we look at letters that are different colors. The colors doesn't affect the classification of the letter.  So a network that only pays attention to the grayscale will perform better.
#
# # Statistical Invariance
# We have an image, we want our network to say that it is an image with a cat in it.  The location of the cat shouldn't matter.  If network has to learn about kittens in different positions independently, that is a lot of work that it has to do.  Instead we explicitly tell it that objects in images are largely the same regardless of position.  This is called **translation invariance**. Defferent positions, same kitten.  Same with text and the position of kitten.  We achieve this using **weight sharing.** When we know that two inputs can contain the same kind of information, we share their weights. Train weights jointly for those inputs.  **Statistical invariants** -things that don't change on average across time or space.  For images, the idea of weight sharing will get us to study convolutional networks.  Text will lead us to embedding and recurring NN.
#
# # Convolutional Networks (Convnets)
# **Neural networks that share their parameters across space**
#
# Imagine an image as a flat pancake with a width, height, and depth (r,g,b). This is the input.  Now we take a tiny patch of the image and run a tiny NN on it with **k** outputs.  Slide NN across the image, without changing the weights.  Slide across and vertically.  On the output we have drawn a different image. Has different width, height, and more importantly, depth.  Have an output that has **k** colored channels.  This operation is called the convolution.  If patch size is whole image, no different than regular layer of NN.  Because of the smaller patch, we have fewer weights and they are shared acros space.  A convnet is basically a deep netwrok where instead of having stacks of matrix multipy layers, we are going to have stacks of convolutions.  It will form a pyramid, bottom is original image that is shallow (rgb).  Apply convolutions that will progressively squeeze the spacial dimensions while increasing the depth.  Corresponds roughly to the semantic complexity of representation.  On top we have the classifier.  Have a representation where all the spacial information has been squeezed out, only params that map to conent of the image remain.
#
# Stride = 1 : roughly same size as input
# Stride = 2 : about half the size.
#
# Roughly because it depends on how we handle edges. If we don't go pass the edge = **'valid' padding**.  Go off the edge and pad with zeros =**'same' padding**. Will produce output that is roughly the same size as the image.
# ![Convnet 1](Lesson8/convnet-1.png)
# ![Convnet 2](Lesson8/convnet-2.png)
#
# # Intuition
# Convolutional NN classifies a golden retriever the same way we do.  It looks at certain parts of the image, such as nose, eyes, etc, and then combines these features.   Does this, but more lower level where it first identifies lines, then it groups those together and so on and so forth.  The cool thing is that the NN does all this learning by itself.  We don't tell it what to look for. It is able to pick out the traits that matter.
#
# ![Heirarchy](Lesson8/heirarchy-diagram.jpg)
#
# # Filters
# ## Breaking up an Image
# First we need to break up an image.  This is done by selectin a width and height that defines a filter.  The filter looks at patches that are the same size.  We slide the filter around the image so it can examine different paches.  **Stride** is the amount by which the filter slides.  The stride is another parameter we can tune.  Increasing the stride reduces the size of the model because it reduces the total patches each layer observes.  Comes with a reduction in accuracy.
#
# An important thing about this is that we group together adjacent pixels and treat them as a collective.  We ignore this in a non-convolutional NN.  This is because a normal NN connects every pixel in the input image to a neuron in the next layer.  Pixels in images are close together for a reason.  The CNN learns to classify local patterns, like shapes and objects.
#
# ## Filter Depth
# It's common to have more than one filter.  Different filters pick up different qualities of a patch (i.e. color, shape, etc)  Number of filters is called the **filter depth**
#
# We connect each patch of pixels to **k** neurons in the next layer, **k** is the filter depth.  So the next layer has a height of **k**.  It is a hyperparameter that we can tune.
#
# We connect a single patch to multiple neurons in the next level because a patch can contain many interst characteristics (i.e. tongue, teeth, fur)
#
# **Same** padding equations:
# ```python
# out_height = ceil(float(in_height) / float(strides[1]))
# out_width  = ceil(float(in_width) / float(strides[2]))
# ```
#
# **Valid** padding equations:
# ```python
# out_height = ceil(float(in_height - filter_height + 1) / float(strides[1]))
# out_width  = ceil(float(in_width - filter_width + 1) / float(strides[2]))
# ```
#
# # Convolutions Cont.
# ![Complete CNN](Lesson8/complete-cnn.png)
# ![Chain Rule With Sharing](Lesson8/chain-with-sharing.png)
#
# # Parameters
# ## Parameter Sharing
# We don't care where on the image a cat is present, we want to still be able to classify it as a cat.  Classification of a given pathch is determined by the weights and biases corresponding to that patch.  If we want a cat that's in the top left patch to be classified the same way as a cat in the bottom right patch, we need the weights and biases to be the same.
#
# That's what we do in CNN.  The weights and biases we learn for a given output layer are shared across all patches in a given input layer. As we increase the depth of our filter, the number of weights and biases we have to learn still increase.  **Weights are not shared across the output channel**
#
# Additional benefit: If we did not reuse the same weights across all patches, we would have to learn new parameters for every single patch and hidden layer neuron pairs.  Doesn't scale well. So this helps with translation invariance, and **gives us a smaller, more scalable model**
#
# ## Padding
# If we have a 5x5 grid and a 3x3 patch and did not use padding, then out picture would shrink to 3x3 as well. We need to be able to maintain the same height and width, so we don't have to worry about dimensionality shrinking.  Easy way to achieve this is to add a border of 0's to the original image.  Would expand original image to 7x7 and the next layer image would be 5x5 again.
#
# ## Dimensionality
# Given:
# * our input layer has a width of **W** and a height of **H**
# * our convolution layer has a filter size **F**
# * we have a stride of **S**
# * a padding of **P**
# * and a filter depth of **K**
#
# width of the next layer: **W_out = (W-F+2P)/S + 1**
#
# height of the next layer: **H_out = (H-F+2P)/S + 1**
#
# Depth of the next layer will be equal to the filter depth: **D_out = K**
#
# Output volume: **W_out \* H_out \* D_out **
#
# Knowing the dimensionality of each additional layer helps us understand how large our model is and how our decisions around filter size and stride affect the size of our network.
#
# ## Quiz
# **Setup**
# H = height, W = width, D = depth
# * We have an input of shape 32x32x3 (HxWxD)
# * 20 filters of shape 8x8x3 (HxWxD)
# * A stride of 2 for both the height and width (S)
# * With padding of size 1 (P)
#
# **Answer**
# 14x14x20
#
# ### Code
# ```python
# input = tf.placeholder(tf.float32, (None, 32, 32, 3))
# filter_weights = tf.Variable(tf.truncated_normal((8, 8, 3, 20)) # (height, width, input_depth, output_depth)
# filter_bias = tf.Variable(tf.zeros(20))
# strides = [1, 2, 2, 1] # (batch, height, width, depth)
# padding = 'SAME'
# conv = tf.nn.conv2d(input, filter_weights, strides, padding) + filter_bias
# ```
#
# Shape of **conv** will be [1, 16, 16, 20].  4D because it accounts for batch size.  Why not [1, 14, 14, 20]?  TensorFlow uses a different padding algorithm.  If using **'VALIS'** it would produce [1, 13, 13, 20]
#
# **SAME Padding**
# ```python
# out_height = ceil(float(in_height) / float(strides[1]))
#
# out_width = ceil(float(in_width) / float(strides[2]))
# ```
#
# **VALID Padding**
# ```python
# out_height = ceil(float(in_height - filter_height + 1) / float(strides[1]))
#
# out_width = ceil(float(in_width - filter_width + 1) / float(strides[2]))
# ```
# ## Quiz: Number of Parameters
# ### Setup
# H = height, W = width, D = depth
#
# * We have an input of shape 32x32x3 (HxWxD)
# * 20 filters of shape 8x8x3 (HxWxD)
# * A stride of 2 for both the height and width (S)
# * Zero padding of size 1 (P)
#
# ### Output Layer
# * 14x14x20 (HxWxD)
#
# ### Hint
# Without parameter sharing, each neuron in the output layer must connect to each neuron in the filter. In addition, each neuron in the output layer must also connect to a single bias neuron.
#
# ### Solution
# (8\*8\*3+1)\*(14\*14\*20) = 756560
#
# 8 \* 8 \* 3 is the number of weights, we add 1 for the bias. Remember, each weight is assigned to every single part of the output (14 \* 14 \* 20). So we multiply these two numbers together and we get the final answer.
#
# ## Quiz: Parameter Sharing
# This is the number of parameters actually used in a convolution layer (**tf.nn.conv2d()**)
# ### Setup
# H = height, W = width, D = depth
#
# * We have an input of shape 32x32x3 (HxWxD)
# * 20 filters of shape 8x8x3 (HxWxD)
# * A stride of 2 for both the height and width (S)
# * Zero padding of size 1 (P)
#
# ### Output Layer
# * 14x14x20 (HxWxD)
#
# ### Hint
# With parameter sharing, each neuron in an output channel shares its weights with every other neuron in that channel. So the number of parameters is equal to the number of neurons in the filter, plus a bias neuron, all multiplied by the number of channels in the output layer.
#
# ### Solution
# (8\*8\*3+1)\*(20) = 3860
#
# That's 3840 weights and 20 biases. This should look similar to the answer from the previous quiz. The difference being it's just 20 instead of (14 \* 14 \* 20). Remember, with weight sharing we use the same filter for an entire depth slice. Because of this we can get rid of 14 \* 14 and be left with only 20.
#
# # Visualizing CNNs
# From [Visualizing and Understanding Convolutional Networks](http://www.matthewzeiler.com/pubs/arxive2013/eccv2014.pdf).  We will see what each layer detects and how each layer detects more and more complex ideas.
#
# ## Layer 1
# ![Layer 1](Lesson8/layer-1-grid.png)
#
# Patterns that cause activations in the first layer.  Range from simple diagonal lines to green blobs.  These are the patterns that the first layer recognizes. Top left shows a -45 degree angle, and top middle shows +45.
#
# ![Layer 1 activations](Lesson8/grid-layer-1.png)
# Above images activate the -45 degree line.
#
# ## Layer 2
# ![Layer 2 grid](Lesson8/layer-2-grid.png)
#
# The second layer captures complex ideas.  Now we have circles and stripes.  **The CNN learns to do this on its own!**
#
# ## Layer 3
# ![Layer 3 grid](Lesson8/layer-3-grid.png)
#
# ## Layer 5
# ![Layer 5 grid](Lesson8/layer-5-grid.png)
#
# # TensorFlow Convolution Layer
# How to implement a CNN in TensorFlow
# Uses **tf.nn.conv2d()** and **tf.nn.bias_add()**

# %%
# Output depth
k_output = 64

# Image Properties
image_width = 10
image_height = 10
color_channels = 3

# Convolution filter
filter_size_width = 5
filter_size_height = 5

# Input/Image
input = tf.placeholder(
    tf.float32,
    shape=[None, image_height, image_width, color_channels])

# Weight and bias
weight = tf.Variable(tf.truncated_normal(
    [filter_size_height, filter_size_width, color_channels, k_output]))
bias = tf.Variable(tf.zeros(k_output))

# Apply Convolution
conv_layer = tf.nn.conv2d(input, weight, strides=[1, 2, 2, 1], padding='SAME')
# Add bias
conv_layer = tf.nn.bias_add(conv_layer, bias)
# Apply activation function
conv_layer = tf.nn.relu(conv_layer)

# %% [markdown]
# TensorFlow uses a stride for each **input** dimension, **[batch, input_height, input_width, input_channels]**. Generally going to set the strides for **batch** and **input_channels** to 1.
#
# **tf.nn.bias_add()** adds a 1-d bias to the last dimension in a matrix.
#
# # Explore the Design Space
# ## Advanced Convnet-ology
# * Pooling
# * 1x1 Convolutions
# * Inception
#
# ## Pooling
# Better way to reduce the spacial extent of the feature maps of the convolutional pyramid.  We currently use striding.  This is very agressive way to sample image.  Removes a lot of information.
#
# Why use pooling? If we use a stride of 1, the output image will never get smaller, it would be the same size as the previous layer.  This is bad because it makes our model larger.  If we have a stride of 2 or more then we tend to loose a lot of information.  So the solution is to use pooling.  In one layer we will use a stride on 1.  Then in the next layer we will apply pooling.  We look at neighboring pixels and combine them (using max, ave, etc) to produce a smaller image.
# ![Pooling](Lesson8/pooling.png)
#
# ![Max Pooling](Lesson8/max-pooling.png)
#
# More expensive because the convolutions have a smaller stride.
#
# ### Typical Architecture
# ![CNN Architecture](Lesson8/cnn-arch.png)
#
# # TensorFlow Max Pooling
# ![Mac Pooling](Lesson8/max-pooling-2.png)
# By Aphex34 (Own work) [CC BY-SA 4.0 (http://creativecommons.org/licenses/by-sa/4.0)], via Wikimedia Commons
#
# **Max pooling with a 2x2 filter and stride of 2**
#
# The benefi of the max pooling operation is to reduce the size of the input, and allow the NN to focus on only the most important elements.  Does this by only retaining the max value for each filter area, and removing the remaining values.
#
# TensorFlow provides **tf.nn.max_pooling()**

# %%
conv_layer = tf.nn.conv2d(input, weight, strides=[1, 2, 2, 1], padding='SAME')
conv_layer = tf.nn.bias_add(conv_layer, bias)
conv_layer = tf.nn.relu(conv_layer)
# Apply Max Pooling
conv_layer = tf.nn.max_pool(
    conv_layer,
    ksize=[1, 2, 2, 1],
    strides=[1, 2, 2, 1],
    padding='SAME')

# %% [markdown]
# **tf.nn.max_pooling()** performs max pooling with the **ksize** as the size of the filter and the **strides** as the length of the stride.  2x2 filter with a strid 2x2 are comming in practice.  Params are structured as 4-element lists, with each element corresponding to a dimension of the input tensor ([batch, height, width, channels]).  Batch and channels dimensions are typically 1.
#
# Recents pooling layers have fallen out of favor because:
# * Recent datasets are so big and complex we're more concerned about underfitting.
# * Dropout is a much better regularizer.
# * Pooling results in a loss of information. Think about the max pooling operation as an example. We only keep the largest of n numbers, thereby disregarding n-1 numbers completely.
#
# ## Quiz: Pooling Mechanics
# ### Setup
# H = height, W = width, D = depth
#
# * We have an input of shape 4x4x5 (HxWxD)
# * Filter of shape 2x2 (HxW)
# * A stride of 2 for both the height and width (S)
# Recall the formula for calculating the new height or width:
# ```python
# new_height = (input_height - filter_height)/S + 1
# new_width = (input_width - filter_width)/S + 1
# ```
#
# **What's the shape of the output? Format is HxWxD.**
# 2x2x5
# ### Code
# Output shape of **pool** will be [1, 2, 2, 5] even if **padding** is changed to **'SAME'**.

# %%
input = tf.placeholder(tf.float32, (None, 4, 4, 5))
filter_shape = [1, 2, 2, 1]
strides = [1, 2, 2, 1]
padding = 'VALID'
pool = tf.nn.max_pool(input, filter_shape, strides, padding)

# %% [markdown]
# # 1x1 Convolution
# ![1x1 convolutions](Lesson8/1x1-conv.png)
# * We have a mini nn over a patch instead of a linear classifier
# * Inexpensive way to make model deeper and have more parameters without completely changing its structure
# * Very cheap, they are just matrix multiply and have relatively few params
#
# # Inception Modules
# ![Inception Model](Lesson8/inception.png)
#
# # Convolution Network in TensorFlow
# The structure of this network follows the classic structure of CNNs, which is a mix of convolution layers and max pooling, followed by fully-connected layers.  Thanks to [Aymeric Damien](https://github.com/aymericdamien/TensorFlow-Examples) for providing the original TensorFlow model.
#
# ## Dataset
# We will again be exploring the MNIST dataset

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets(".", one_hot=True, reshape=False)

import tensorflow as tf

# Parameters
learning_rate = 0.00001
epochs = 10
batch_size = 128

# Number of samples to calculate validation and accuracy
# Decrease this if you're running out of memory to calculate accuracy
test_valid_size = 256

# Network Parameters
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# Store layers weight and bias
weights = {
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    'out': tf.Variable(tf.random_normal([1024, n_classes]))}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))}

def conv2d(x, W, b, strides=1):
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)

def maxpool2d(x, k=2):
    return tf.nn.max_pool(
        x,
        ksize=[1, k, k, 1],
        strides=[1, k, k, 1],
        padding='SAME')

def conv_net(x, weights, biases, dropout):
    # Layer 1 - 28*28*1 to 14*14*32
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    conv1 = maxpool2d(conv1, k=2)
    
    # Layer 2 - 14*14*32 to 7*7*64
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    conv2 = maxpool2d(conv2, k=2)
    
    # Fully connected layer - 7*7*64 to 1024
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    fc1 = tf.nn.dropout(fc1, dropout)
    
    # Output Layer - class prediction - 1024 to 10
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# tf Graph input
x = tf.placeholder(tf.float32, [None, 28, 28, 1])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32)

# Model
logits = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(\
    tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)\
    .minimize(cost)
    
# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initialize variables
init = tf.global_variables_initializer()

# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    
    for epoch in range(epochs):
        for batch in range(mnist.train.num_examples//batch_size):
            batch_x, batch_y = mnist.train.next_batch(batch_size)
            sess.run(optimizer, feed_dict={
                x: batch_x,
                y: batch_y,
                keep_prob: dropout})
            
            # Calculate batch loss and accuracy
            loss = sess.run(cost, feed_dict={
                x: batch_x,
                y: batch_y,
                keep_prob: 1.})
            valid_acc = sess.run(accuracy, feed_dict={
                x: mnist.validation.images[:test_valid_size],
                y: mnist.validation.labels[:test_valid_size],
                keep_prob: 1.})
            
            print('Epoch {:>2}, Batch {:>3} -'
                  'Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(
                  epoch + 1,
                  batch + 1,
                  loss,
                  valid_acc))
            
        # Calculate Test Accuracy
        test_acc = sess.run(accuracy, feed_dict={
            x: mnist.test.images[:test_valid_size],
            y: mnist.test.labels[:test_valid_size],
            keep_prob: 1.})
        print('Testing Accuracy: {}'.format(test_acc))
# Out:
# Extracting .\train-images-idx3-ubyte.gz
# Extracting .\train-labels-idx1-ubyte.gz
# Extracting .\t10k-images-idx3-ubyte.gz
# Extracting .\t10k-labels-idx1-ubyte.gz
# Epoch  1, Batch   1 -Loss: 59164.2656 Validation Accuracy: 0.085938
# Epoch  1, Batch   2 -Loss: 43841.5273 Validation Accuracy: 0.093750
# Epoch  1, Batch   3 -Loss: 42512.7734 Validation Accuracy: 0.074219
# Epoch  1, Batch   4 -Loss: 36167.4297 Validation Accuracy: 0.066406
# Epoch  1, Batch   5 -Loss: 38407.0078 Validation Accuracy: 0.074219
# Epoch  1, Batch   6 -Loss: 29824.0762 Validation Accuracy: 0.082031
# Epoch  1, Batch   7 -Loss: 28880.4922 Validation Accuracy: 0.105469
# Epoch  1, Batch   8 -Loss: 28233.3965 Validation Accuracy: 0.109375
# Epoch  1, Batch   9 -Loss: 27130.5859 Validation Accuracy: 0.136719
# Epoch  1, Batch  10 -Loss: 28684.4922 Validation Accuracy: 0.128906
# Epoch  1, Batch  11 -Loss: 25472.8418 Validation Accuracy: 0.109375
# Epoch  1, Batch  12 -Loss: 25876.5625 Validation Accuracy: 0.125000
# Epoch  1, Batch  13 -Loss: 25292.0586 Validation Accuracy: 0.125000
# Epoch  1, Batch  14 -Loss: 23531.2266 Validation Accuracy: 0.132812
# Epoch  1, Batch  15 -Loss: 23851.4609 Validation Accuracy: 0.132812
# Epoch  1, Batch  16 -Loss: 24317.7812 Validation Accuracy: 0.144531
# Epoch  1, Batch  17 -Loss: 19255.2012 Validation Accuracy: 0.152344
# Epoch  1, Batch  18 -Loss: 17665.5840 Validation Accuracy: 0.156250
# Epoch  1, Batch  19 -Loss: 19677.5352 Validation Accuracy: 0.164062
# Epoch  1, Batch  20 -Loss: 19537.9180 Validation Accuracy: 0.164062
# Epoch  1, Batch  21 -Loss: 19213.3164 Validation Accuracy: 0.183594
# Epoch  1, Batch  22 -Loss: 14335.0010 Validation Accuracy: 0.179688
# Epoch  1, Batch  23 -Loss: 16056.5439 Validation Accuracy: 0.175781
# Epoch  1, Batch  24 -Loss: 15793.6074 Validation Accuracy: 0.187500
# Epoch  1, Batch  25 -Loss: 16097.5400 Validation Accuracy: 0.187500
# Epoch  1, Batch  26 -Loss: 14615.3145 Validation Accuracy: 0.210938
# Epoch  1, Batch  27 -Loss: 12525.5781 Validation Accuracy: 0.214844
# Epoch  1, Batch  28 -Loss: 13220.9092 Validation Accuracy: 0.222656
# Epoch  1, Batch  29 -Loss: 12464.2441 Validation Accuracy: 0.214844
# Epoch  1, Batch  30 -Loss: 11711.3809 Validation Accuracy: 0.207031
# Epoch  1, Batch  31 -Loss: 13734.1133 Validation Accuracy: 0.210938
# Epoch  1, Batch  32 -Loss: 14953.7871 Validation Accuracy: 0.234375
# Epoch  1, Batch  33 -Loss: 11478.4385 Validation Accuracy: 0.242188
# Epoch  1, Batch  34 -Loss: 12796.8184 Validation Accuracy: 0.257812
# Epoch  1, Batch  35 -Loss: 12436.9072 Validation Accuracy: 0.269531
# Epoch  1, Batch  36 -Loss: 13743.3975 Validation Accuracy: 0.261719
# Epoch  1, Batch  37 -Loss: 10916.6650 Validation Accuracy: 0.265625
# Epoch  1, Batch  38 -Loss:  9143.3398 Validation Accuracy: 0.273438
# Epoch  1, Batch  39 -Loss: 10638.2598 Validation Accuracy: 0.285156
# Epoch  1, Batch  40 -Loss: 11140.8262 Validation Accuracy: 0.285156
# Epoch  1, Batch  41 -Loss:  8798.0078 Validation Accuracy: 0.308594
# Epoch  1, Batch  42 -Loss:  9603.3359 Validation Accuracy: 0.312500
# Epoch  1, Batch  43 -Loss:  7912.6992 Validation Accuracy: 0.312500
# Epoch  1, Batch  44 -Loss:  9070.0508 Validation Accuracy: 0.308594
# Epoch  1, Batch  45 -Loss:  8639.5381 Validation Accuracy: 0.304688
# Epoch  1, Batch  46 -Loss:  9730.1328 Validation Accuracy: 0.308594
# Epoch  1, Batch  47 -Loss:  8635.9297 Validation Accuracy: 0.320312
# Epoch  1, Batch  48 -Loss:  6866.1646 Validation Accuracy: 0.332031
# Epoch  1, Batch  49 -Loss:  7518.4062 Validation Accuracy: 0.324219
# Epoch  1, Batch  50 -Loss:  7233.0884 Validation Accuracy: 0.339844
# Epoch  1, Batch  51 -Loss:  7523.7393 Validation Accuracy: 0.343750
# Epoch  1, Batch  52 -Loss:  9679.3506 Validation Accuracy: 0.343750
# Epoch  1, Batch  53 -Loss:  8205.3203 Validation Accuracy: 0.339844
# Epoch  1, Batch  54 -Loss:  7510.9072 Validation Accuracy: 0.359375
# Epoch  1, Batch  55 -Loss:  6494.5293 Validation Accuracy: 0.351562
# Epoch  1, Batch  56 -Loss:  6177.3271 Validation Accuracy: 0.367188
# Epoch  1, Batch  57 -Loss:  8255.0098 Validation Accuracy: 0.367188
# Epoch  1, Batch  58 -Loss:  8936.7949 Validation Accuracy: 0.355469
# Epoch  1, Batch  59 -Loss:  9197.7832 Validation Accuracy: 0.363281
# Epoch  1, Batch  60 -Loss:  9565.6006 Validation Accuracy: 0.378906
# Epoch  1, Batch  61 -Loss:  8564.3203 Validation Accuracy: 0.375000
# Epoch  1, Batch  62 -Loss:  8077.2891 Validation Accuracy: 0.375000
# Epoch  1, Batch  63 -Loss:  8730.5029 Validation Accuracy: 0.390625
# Epoch  1, Batch  64 -Loss:  9131.3516 Validation Accuracy: 0.406250
# Epoch  1, Batch  65 -Loss:  6371.2002 Validation Accuracy: 0.398438
# Epoch  1, Batch  66 -Loss:  5441.1641 Validation Accuracy: 0.402344
# Epoch  1, Batch  67 -Loss:  6287.0981 Validation Accuracy: 0.410156
# Epoch  2, Batch  10 -Loss:  1204.3936 Validation Accuracy: 0.734375
# Epoch  2, Batch  11 -Loss:  1887.9136 Validation Accuracy: 0.730469
# Epoch  2, Batch  12 -Loss:   702.2332 Validation Accuracy: 0.734375
# Epoch  2, Batch  13 -Loss:  1133.8403 Validation Accuracy: 0.726562
# Epoch  2, Batch  14 -Loss:  1598.2302 Validation Accuracy: 0.738281
# Epoch  2, Batch  15 -Loss:  2207.4456 Validation Accuracy: 0.730469
# Epoch  2, Batch  16 -Loss:  1375.2679 Validation Accuracy: 0.734375
# Epoch  2, Batch  17 -Loss:  1712.2773 Validation Accuracy: 0.726562
# Epoch  2, Batch  18 -Loss:  1672.3444 Validation Accuracy: 0.726562
# Epoch  2, Batch  19 -Loss:  1400.0852 Validation Accuracy: 0.726562
# Epoch  2, Batch  20 -Loss:  1679.4143 Validation Accuracy: 0.722656
# Epoch  2, Batch  21 -Loss:  1130.0752 Validation Accuracy: 0.726562
# Epoch  2, Batch  22 -Loss:  1040.3406 Validation Accuracy: 0.722656
# Epoch  2, Batch  23 -Loss:  1356.3674 Validation Accuracy: 0.726562
# Epoch  2, Batch  24 -Loss:  1183.6687 Validation Accuracy: 0.722656
# Epoch  2, Batch  25 -Loss:  1447.7024 Validation Accuracy: 0.722656
# Epoch  2, Batch  26 -Loss:  1368.0139 Validation Accuracy: 0.730469
# Epoch  2, Batch  27 -Loss:   981.4578 Validation Accuracy: 0.726562
# Epoch  2, Batch  28 -Loss:  1636.1407 Validation Accuracy: 0.730469
# Epoch  2, Batch  29 -Loss:  1512.9912 Validation Accuracy: 0.730469
# Epoch  2, Batch  30 -Loss:  1549.9602 Validation Accuracy: 0.730469
# Epoch  2, Batch  31 -Loss:  1525.0958 Validation Accuracy: 0.730469
# Epoch  2, Batch  32 -Loss:  1480.8330 Validation Accuracy: 0.734375
# Epoch  2, Batch  33 -Loss:  1462.9791 Validation Accuracy: 0.726562
# Epoch  2, Batch  34 -Loss:  1698.4037 Validation Accuracy: 0.726562
# Epoch  2, Batch  35 -Loss:  2004.4152 Validation Accuracy: 0.726562
# Epoch  2, Batch  36 -Loss:  1069.1030 Validation Accuracy: 0.730469
# Epoch  2, Batch  37 -Loss:  1224.5304 Validation Accuracy: 0.734375
# Epoch  2, Batch  38 -Loss:  1651.5516 Validation Accuracy: 0.734375
# Epoch  2, Batch  39 -Loss:  1271.5912 Validation Accuracy: 0.730469
# Epoch  2, Batch  40 -Loss:   897.9812 Validation Accuracy: 0.734375
# Epoch  2, Batch  41 -Loss:  1035.9852 Validation Accuracy: 0.734375
# Epoch  2, Batch  42 -Loss:  1984.2560 Validation Accuracy: 0.734375
# Epoch  2, Batch  43 -Loss:  1567.1001 Validation Accuracy: 0.730469
# Epoch  2, Batch  44 -Loss:  1538.3469 Validation Accuracy: 0.734375
# Epoch  2, Batch  45 -Loss:  1606.1440 Validation Accuracy: 0.734375
# Epoch  2, Batch  46 -Loss:  1232.5315 Validation Accuracy: 0.730469
# Epoch  2, Batch  47 -Loss:  1661.7869 Validation Accuracy: 0.734375
# Epoch  2, Batch  48 -Loss:  1235.1382 Validation Accuracy: 0.734375
# Epoch  2, Batch  49 -Loss:  1361.8052 Validation Accuracy: 0.730469
# Epoch  2, Batch  50 -Loss:  1731.4125 Validation Accuracy: 0.726562
# Epoch  2, Batch  51 -Loss:   751.0844 Validation Accuracy: 0.738281
# Epoch  2, Batch  52 -Loss:  1246.0289 Validation Accuracy: 0.730469
# Epoch  2, Batch  53 -Loss:  1589.4717 Validation Accuracy: 0.730469
# Epoch  2, Batch  54 -Loss:   925.0667 Validation Accuracy: 0.734375
# Epoch  2, Batch  55 -Loss:  1255.8031 Validation Accuracy: 0.734375
# Epoch  2, Batch  56 -Loss:  1164.3390 Validation Accuracy: 0.734375
# Epoch  2, Batch  57 -Loss:   834.5183 Validation Accuracy: 0.738281
# Epoch  2, Batch  58 -Loss:  1092.6074 Validation Accuracy: 0.734375
# Epoch  2, Batch  59 -Loss:  1255.2531 Validation Accuracy: 0.738281
# Epoch  2, Batch  60 -Loss:   860.6106 Validation Accuracy: 0.738281
# Epoch  2, Batch  61 -Loss:  1279.9652 Validation Accuracy: 0.734375
# Epoch  2, Batch  62 -Loss:  1542.4507 Validation Accuracy: 0.734375
# Epoch  2, Batch  63 -Loss:  1276.5121 Validation Accuracy: 0.738281
# Epoch  2, Batch  64 -Loss:  1193.1421 Validation Accuracy: 0.738281
# Epoch  2, Batch  65 -Loss:  1711.9819 Validation Accuracy: 0.734375
# Epoch  2, Batch  66 -Loss:  1541.0630 Validation Accuracy: 0.738281
# Epoch  2, Batch  67 -Loss:  1512.1440 Validation Accuracy: 0.730469
# Epoch  2, Batch  68 -Loss:   885.6002 Validation Accuracy: 0.730469
# Epoch  2, Batch  69 -Loss:  1432.8156 Validation Accuracy: 0.730469
# Epoch  2, Batch  70 -Loss:   981.9828 Validation Accuracy: 0.730469
# Epoch  2, Batch  71 -Loss:   836.3164 Validation Accuracy: 0.730469
# Epoch  2, Batch  72 -Loss:  1430.0559 Validation Accuracy: 0.726562
# Epoch  2, Batch  73 -Loss:  1087.5825 Validation Accuracy: 0.726562
# Epoch  2, Batch  74 -Loss:  1530.2537 Validation Accuracy: 0.730469
# Epoch  2, Batch  75 -Loss:  1359.8560 Validation Accuracy: 0.730469
# Epoch  2, Batch  76 -Loss:  1092.3206 Validation Accuracy: 0.726562
# Epoch  2, Batch  77 -Loss:  1022.9492 Validation Accuracy: 0.734375
# Epoch  2, Batch  78 -Loss:  1317.3175 Validation Accuracy: 0.730469
# Epoch  2, Batch  79 -Loss:  1745.6313 Validation Accuracy: 0.730469
# Epoch  2, Batch  80 -Loss:  1584.4556 Validation Accuracy: 0.734375
# Epoch  2, Batch  81 -Loss:   901.5000 Validation Accuracy: 0.730469
# Epoch  2, Batch  82 -Loss:  1158.9464 Validation Accuracy: 0.730469
# Epoch  2, Batch  83 -Loss:  1428.1008 Validation Accuracy: 0.730469
# Epoch  2, Batch  84 -Loss:  1351.3368 Validation Accuracy: 0.734375
# Epoch  2, Batch  85 -Loss:  1137.2271 Validation Accuracy: 0.730469
# Epoch  2, Batch  86 -Loss:  1139.1392 Validation Accuracy: 0.730469
# Epoch  2, Batch  87 -Loss:  1259.4596 Validation Accuracy: 0.734375
# Epoch  2, Batch  88 -Loss:  1734.9780 Validation Accuracy: 0.738281
# Epoch  2, Batch  89 -Loss:  1218.5189 Validation Accuracy: 0.738281
# Epoch  2, Batch  90 -Loss:  1291.8193 Validation Accuracy: 0.734375
# Epoch  2, Batch  91 -Loss:  1327.4449 Validation Accuracy: 0.738281
# Epoch  2, Batch  92 -Loss:  1478.4380 Validation Accuracy: 0.738281
# Epoch  2, Batch  93 -Loss:  1324.1851 Validation Accuracy: 0.738281
# Epoch  2, Batch  94 -Loss:  1752.8889 Validation Accuracy: 0.742188
# Epoch  2, Batch  95 -Loss:  1488.1356 Validation Accuracy: 0.746094
# Epoch  2, Batch  96 -Loss:   988.7354 Validation Accuracy: 0.746094
# Epoch  2, Batch  97 -Loss:  1757.3201 Validation Accuracy: 0.746094
# Epoch  2, Batch  98 -Loss:  1077.5481 Validation Accuracy: 0.742188
# Epoch  2, Batch  99 -Loss:  1198.6249 Validation Accuracy: 0.742188
# Epoch  2, Batch 100 -Loss:  1052.6609 Validation Accuracy: 0.742188
# Epoch  2, Batch 101 -Loss:  1458.9990 Validation Accuracy: 0.742188
# Epoch  2, Batch 102 -Loss:  1570.4299 Validation Accuracy: 0.738281
# Epoch  2, Batch 103 -Loss:  1330.4261 Validation Accuracy: 0.738281
# Epoch  2, Batch 104 -Loss:  1434.3357 Validation Accuracy: 0.738281
# Epoch  2, Batch 105 -Loss:  1298.6165 Validation Accuracy: 0.734375
# Epoch  2, Batch 106 -Loss:  1020.9585 Validation Accuracy: 0.734375
# Epoch  2, Batch 107 -Loss:  1066.1968 Validation Accuracy: 0.742188
# Epoch  2, Batch 108 -Loss:  1203.4132 Validation Accuracy: 0.738281
# Epoch  2, Batch 109 -Loss:   947.5503 Validation Accuracy: 0.742188
# Epoch  2, Batch 110 -Loss:  1134.0933 Validation Accuracy: 0.742188
# Epoch  2, Batch 111 -Loss:  1027.5817 Validation Accuracy: 0.746094
# Epoch  2, Batch 112 -Loss:  1018.8962 Validation Accuracy: 0.746094
# Epoch  2, Batch 113 -Loss:  1406.1865 Validation Accuracy: 0.742188
# Epoch  2, Batch 114 -Loss:  1681.9501 Validation Accuracy: 0.746094
# Epoch  2, Batch 115 -Loss:   626.2982 Validation Accuracy: 0.742188
# Epoch  2, Batch 116 -Loss:   569.0371 Validation Accuracy: 0.738281
# Epoch  2, Batch 117 -Loss:  1078.6077 Validation Accuracy: 0.746094
# Epoch  2, Batch 118 -Loss:   811.7919 Validation Accuracy: 0.746094
# Epoch  2, Batch 119 -Loss:   889.0056 Validation Accuracy: 0.746094
# Epoch  2, Batch 120 -Loss:  1278.6250 Validation Accuracy: 0.753906
# Epoch  2, Batch 121 -Loss:   843.6626 Validation Accuracy: 0.753906
# Epoch  2, Batch 271 -Loss:  1187.0128 Validation Accuracy: 0.757812
# Epoch  2, Batch 272 -Loss:   675.3063 Validation Accuracy: 0.761719
# Epoch  2, Batch 273 -Loss:   778.9872 Validation Accuracy: 0.757812
# Epoch  2, Batch 274 -Loss:  1413.0735 Validation Accuracy: 0.757812
# ...
# Epoch 10, Batch 196 -Loss:   279.2908 Validation Accuracy: 0.871094
# Epoch 10, Batch 197 -Loss:   227.6140 Validation Accuracy: 0.871094
# Epoch 10, Batch 198 -Loss:   125.8557 Validation Accuracy: 0.871094
# Epoch 10, Batch 199 -Loss:   232.7152 Validation Accuracy: 0.871094
# Epoch 10, Batch 200 -Loss:   353.6025 Validation Accuracy: 0.871094
# Epoch 10, Batch 201 -Loss:   237.0066 Validation Accuracy: 0.871094
# Epoch 10, Batch 202 -Loss:   210.3812 Validation Accuracy: 0.875000
# Epoch 10, Batch 203 -Loss:   283.7278 Validation Accuracy: 0.871094
# Epoch 10, Batch 204 -Loss:   338.0894 Validation Accuracy: 0.871094
# Epoch 10, Batch 205 -Loss:   291.7104 Validation Accuracy: 0.871094
# Epoch 10, Batch 206 -Loss:   201.7325 Validation Accuracy: 0.871094
# Epoch 10, Batch 207 -Loss:   146.0977 Validation Accuracy: 0.871094
# Epoch 10, Batch 208 -Loss:   294.3127 Validation Accuracy: 0.871094
# Epoch 10, Batch 209 -Loss:   169.8480 Validation Accuracy: 0.871094
# Epoch 10, Batch 210 -Loss:   236.0854 Validation Accuracy: 0.871094
# Epoch 10, Batch 211 -Loss:   209.0357 Validation Accuracy: 0.875000
# Epoch 10, Batch 212 -Loss:   326.0150 Validation Accuracy: 0.875000
# Epoch 10, Batch 213 -Loss:   210.5339 Validation Accuracy: 0.878906
# Epoch 10, Batch 214 -Loss:   292.5609 Validation Accuracy: 0.878906
# Epoch 10, Batch 215 -Loss:   399.2570 Validation Accuracy: 0.878906
# Epoch 10, Batch 216 -Loss:   296.2837 Validation Accuracy: 0.878906
# Epoch 10, Batch 217 -Loss:   289.5340 Validation Accuracy: 0.878906
# Epoch 10, Batch 218 -Loss:   135.8711 Validation Accuracy: 0.878906
# Epoch 10, Batch 219 -Loss:   394.0149 Validation Accuracy: 0.878906
# Epoch 10, Batch 220 -Loss:   341.5803 Validation Accuracy: 0.878906
# Epoch 10, Batch 221 -Loss:   217.3094 Validation Accuracy: 0.878906
# Epoch 10, Batch 222 -Loss:   204.1601 Validation Accuracy: 0.875000
# Epoch 10, Batch 223 -Loss:   282.5774 Validation Accuracy: 0.875000
# Epoch 10, Batch 224 -Loss:   258.3875 Validation Accuracy: 0.875000
# Epoch 10, Batch 225 -Loss:   364.8794 Validation Accuracy: 0.878906
# Epoch 10, Batch 226 -Loss:   219.5705 Validation Accuracy: 0.875000
# Epoch 10, Batch 227 -Loss:   169.5813 Validation Accuracy: 0.871094
# Epoch 10, Batch 228 -Loss:   292.5888 Validation Accuracy: 0.871094
# Epoch 10, Batch 229 -Loss:   178.5367 Validation Accuracy: 0.867188
# Epoch 10, Batch 230 -Loss:   436.4344 Validation Accuracy: 0.867188
# Epoch 10, Batch 231 -Loss:   248.4147 Validation Accuracy: 0.867188
# Epoch 10, Batch 232 -Loss:   228.3659 Validation Accuracy: 0.863281
# Epoch 10, Batch 233 -Loss:   311.9289 Validation Accuracy: 0.867188
# Epoch 10, Batch 234 -Loss:   375.5106 Validation Accuracy: 0.871094
# Epoch 10, Batch 235 -Loss:   313.3958 Validation Accuracy: 0.867188
# Epoch 10, Batch 236 -Loss:   251.4504 Validation Accuracy: 0.863281
# Epoch 10, Batch 237 -Loss:   383.3436 Validation Accuracy: 0.867188
# Epoch 10, Batch 238 -Loss:   201.4239 Validation Accuracy: 0.863281
# Epoch 10, Batch 239 -Loss:   185.6957 Validation Accuracy: 0.863281
# Epoch 10, Batch 240 -Loss:   181.2530 Validation Accuracy: 0.867188
# Epoch 10, Batch 241 -Loss:   184.6875 Validation Accuracy: 0.867188
# Epoch 10, Batch 242 -Loss:   285.9664 Validation Accuracy: 0.867188
# Epoch 10, Batch 243 -Loss:   231.8119 Validation Accuracy: 0.867188
# Epoch 10, Batch 244 -Loss:   230.1477 Validation Accuracy: 0.867188
# Epoch 10, Batch 245 -Loss:   181.1276 Validation Accuracy: 0.867188
# Epoch 10, Batch 246 -Loss:   403.2656 Validation Accuracy: 0.867188
# Epoch 10, Batch 247 -Loss:    89.9940 Validation Accuracy: 0.863281
# Epoch 10, Batch 248 -Loss:   114.2828 Validation Accuracy: 0.867188
# Epoch 10, Batch 249 -Loss:   185.3171 Validation Accuracy: 0.867188
# Epoch 10, Batch 250 -Loss:   160.4998 Validation Accuracy: 0.867188
# Epoch 10, Batch 251 -Loss:   181.7951 Validation Accuracy: 0.863281
# Epoch 10, Batch 252 -Loss:   158.2990 Validation Accuracy: 0.863281
# Epoch 10, Batch 253 -Loss:   250.9630 Validation Accuracy: 0.871094
# Epoch 10, Batch 254 -Loss:   211.0979 Validation Accuracy: 0.875000
# Epoch 10, Batch 255 -Loss:   257.0684 Validation Accuracy: 0.871094
# Epoch 10, Batch 256 -Loss:   173.1801 Validation Accuracy: 0.871094
# Epoch 10, Batch 257 -Loss:   281.2619 Validation Accuracy: 0.871094
# Epoch 10, Batch 258 -Loss:   126.5642 Validation Accuracy: 0.867188
# Epoch 10, Batch 259 -Loss:   210.9979 Validation Accuracy: 0.867188
# Epoch 10, Batch 260 -Loss:   187.7278 Validation Accuracy: 0.863281
# Epoch 10, Batch 261 -Loss:   205.7101 Validation Accuracy: 0.867188
# Epoch 10, Batch 262 -Loss:   264.7886 Validation Accuracy: 0.871094
# Epoch 10, Batch 263 -Loss:   201.7922 Validation Accuracy: 0.871094
# Epoch 10, Batch 264 -Loss:   149.1024 Validation Accuracy: 0.867188
# Epoch 10, Batch 265 -Loss:   381.9664 Validation Accuracy: 0.867188
# Epoch 10, Batch 266 -Loss:   169.4454 Validation Accuracy: 0.859375
# Epoch 10, Batch 267 -Loss:   263.3932 Validation Accuracy: 0.859375
# Epoch 10, Batch 268 -Loss:   316.9139 Validation Accuracy: 0.867188
# Epoch 10, Batch 269 -Loss:   269.0743 Validation Accuracy: 0.875000
# Epoch 10, Batch 270 -Loss:   166.9600 Validation Accuracy: 0.875000
# Epoch 10, Batch 271 -Loss:   267.1419 Validation Accuracy: 0.875000
# Epoch 10, Batch 272 -Loss:   184.3734 Validation Accuracy: 0.875000
# Epoch 10, Batch 273 -Loss:   264.6714 Validation Accuracy: 0.871094
# Epoch 10, Batch 274 -Loss:   182.0275 Validation Accuracy: 0.867188
# Epoch 10, Batch 275 -Loss:   185.3499 Validation Accuracy: 0.867188
# Epoch 10, Batch 276 -Loss:   328.5198 Validation Accuracy: 0.867188
# Epoch 10, Batch 277 -Loss:   295.4182 Validation Accuracy: 0.867188
# Epoch 10, Batch 278 -Loss:   191.5861 Validation Accuracy: 0.867188
# Epoch 10, Batch 279 -Loss:   318.4302 Validation Accuracy: 0.867188
# Epoch 10, Batch 280 -Loss:   252.8761 Validation Accuracy: 0.863281
# Epoch 10, Batch 281 -Loss:   207.9485 Validation Accuracy: 0.863281
# Epoch 10, Batch 282 -Loss:   214.9794 Validation Accuracy: 0.867188
# Epoch 10, Batch 283 -Loss:   182.5975 Validation Accuracy: 0.867188
# Epoch 10, Batch 284 -Loss:   249.3031 Validation Accuracy: 0.863281
# Epoch 10, Batch 285 -Loss:   180.8912 Validation Accuracy: 0.871094
# Epoch 10, Batch 286 -Loss:   131.3450 Validation Accuracy: 0.867188
# Epoch 10, Batch 287 -Loss:   275.1816 Validation Accuracy: 0.871094
# Epoch 10, Batch 288 -Loss:   223.7112 Validation Accuracy: 0.871094
# Epoch 10, Batch 289 -Loss:   174.8145 Validation Accuracy: 0.875000
# Epoch 10, Batch 290 -Loss:   177.7106 Validation Accuracy: 0.875000
# Epoch 10, Batch 291 -Loss:   153.1654 Validation Accuracy: 0.871094
# Epoch 10, Batch 292 -Loss:   307.7550 Validation Accuracy: 0.867188
# Epoch 10, Batch 293 -Loss:   270.6862 Validation Accuracy: 0.871094
# Epoch 10, Batch 294 -Loss:   255.0258 Validation Accuracy: 0.867188
# Epoch 10, Batch 295 -Loss:   142.6971 Validation Accuracy: 0.867188
# Epoch 10, Batch 296 -Loss:   395.9573 Validation Accuracy: 0.867188
# Epoch 10, Batch 297 -Loss:   282.7727 Validation Accuracy: 0.863281
# Epoch 10, Batch 298 -Loss:   200.3923 Validation Accuracy: 0.867188
# Epoch 10, Batch 299 -Loss:   270.3413 Validation Accuracy: 0.863281
# Epoch 10, Batch 300 -Loss:   193.2037 Validation Accuracy: 0.863281
# Epoch 10, Batch 301 -Loss:   191.4389 Validation Accuracy: 0.867188
# Epoch 10, Batch 302 -Loss:   273.5713 Validation Accuracy: 0.867188
# Epoch 10, Batch 303 -Loss:   166.8114 Validation Accuracy: 0.867188
# Epoch 10, Batch 304 -Loss:   112.7917 Validation Accuracy: 0.867188
# Epoch 10, Batch 305 -Loss:   165.4031 Validation Accuracy: 0.863281
# Epoch 10, Batch 306 -Loss:   282.5013 Validation Accuracy: 0.863281
# Epoch 10, Batch 307 -Loss:    88.8573 Validation Accuracy: 0.863281
# Epoch 10, Batch 308 -Loss:   196.3324 Validation Accuracy: 0.863281
# Epoch 10, Batch 309 -Loss:   203.6386 Validation Accuracy: 0.867188
# Epoch 10, Batch 310 -Loss:   230.2959 Validation Accuracy: 0.867188
# Epoch 10, Batch 311 -Loss:   358.6415 Validation Accuracy: 0.867188
# Epoch 10, Batch 312 -Loss:   123.0820 Validation Accuracy: 0.867188
# Epoch 10, Batch 313 -Loss:   277.3811 Validation Accuracy: 0.871094
# Epoch 10, Batch 314 -Loss:    89.1578 Validation Accuracy: 0.867188
# Epoch 10, Batch 315 -Loss:   145.5335 Validation Accuracy: 0.871094
# Epoch 10, Batch 316 -Loss:   239.4830 Validation Accuracy: 0.871094
# Epoch 10, Batch 317 -Loss:   199.5675 Validation Accuracy: 0.867188
# Epoch 10, Batch 318 -Loss:   215.0052 Validation Accuracy: 0.867188
# Epoch 10, Batch 319 -Loss:   150.9349 Validation Accuracy: 0.867188
# Epoch 10, Batch 320 -Loss:   372.5352 Validation Accuracy: 0.871094
# Epoch 10, Batch 321 -Loss:   297.2289 Validation Accuracy: 0.871094
# Epoch 10, Batch 322 -Loss:   269.2979 Validation Accuracy: 0.871094
# Epoch 10, Batch 323 -Loss:   355.1388 Validation Accuracy: 0.871094
# Epoch 10, Batch 324 -Loss:   319.7595 Validation Accuracy: 0.871094
# Epoch 10, Batch 325 -Loss:   209.0327 Validation Accuracy: 0.871094
# Epoch 10, Batch 326 -Loss:   153.2768 Validation Accuracy: 0.867188
# Epoch 10, Batch 327 -Loss:   195.5596 Validation Accuracy: 0.867188
# Epoch 10, Batch 328 -Loss:   249.7268 Validation Accuracy: 0.867188
# Epoch 10, Batch 329 -Loss:   190.4981 Validation Accuracy: 0.867188
# Epoch 10, Batch 330 -Loss:   274.1415 Validation Accuracy: 0.867188
# Epoch 10, Batch 331 -Loss:   271.3748 Validation Accuracy: 0.863281
# Epoch 10, Batch 332 -Loss:   284.9290 Validation Accuracy: 0.867188
# Epoch 10, Batch 333 -Loss:   233.7234 Validation Accuracy: 0.867188
# Epoch 10, Batch 334 -Loss:   152.4921 Validation Accuracy: 0.867188
# Epoch 10, Batch 335 -Loss:   252.9441 Validation Accuracy: 0.867188
# Epoch 10, Batch 336 -Loss:   213.1168 Validation Accuracy: 0.867188
# Epoch 10, Batch 337 -Loss:   182.3387 Validation Accuracy: 0.867188
# Epoch 10, Batch 338 -Loss:   270.4491 Validation Accuracy: 0.867188
# Epoch 10, Batch 339 -Loss:   230.2336 Validation Accuracy: 0.867188
# Epoch 10, Batch 340 -Loss:   369.6375 Validation Accuracy: 0.867188
# Epoch 10, Batch 341 -Loss:   295.8707 Validation Accuracy: 0.867188
# Epoch 10, Batch 342 -Loss:   255.5692 Validation Accuracy: 0.867188
# Epoch 10, Batch 343 -Loss:   199.5114 Validation Accuracy: 0.867188
# Epoch 10, Batch 344 -Loss:   206.3053 Validation Accuracy: 0.867188
# Epoch 10, Batch 345 -Loss:   204.0982 Validation Accuracy: 0.867188
# Epoch 10, Batch 346 -Loss:   194.4641 Validation Accuracy: 0.863281
# Epoch 10, Batch 347 -Loss:   312.3801 Validation Accuracy: 0.863281
# Epoch 10, Batch 348 -Loss:   264.8340 Validation Accuracy: 0.863281
# Epoch 10, Batch 349 -Loss:   184.0248 Validation Accuracy: 0.863281
# Epoch 10, Batch 350 -Loss:   270.4977 Validation Accuracy: 0.867188
# Epoch 10, Batch 351 -Loss:   242.5668 Validation Accuracy: 0.871094
# Epoch 10, Batch 352 -Loss:   318.5145 Validation Accuracy: 0.867188
# Epoch 10, Batch 353 -Loss:   215.5612 Validation Accuracy: 0.871094
# Epoch 10, Batch 354 -Loss:   142.7725 Validation Accuracy: 0.863281
# Epoch 10, Batch 355 -Loss:   112.0224 Validation Accuracy: 0.867188
# Epoch 10, Batch 356 -Loss:   263.3870 Validation Accuracy: 0.867188
# Epoch 10, Batch 357 -Loss:   189.6219 Validation Accuracy: 0.867188
# Epoch 10, Batch 358 -Loss:   296.0899 Validation Accuracy: 0.867188
# Epoch 10, Batch 359 -Loss:   260.0513 Validation Accuracy: 0.867188
# Epoch 10, Batch 360 -Loss:   178.7305 Validation Accuracy: 0.867188
# Epoch 10, Batch 361 -Loss:   361.7392 Validation Accuracy: 0.867188
# Epoch 10, Batch 362 -Loss:   308.3126 Validation Accuracy: 0.867188
# Epoch 10, Batch 363 -Loss:   232.8770 Validation Accuracy: 0.867188
# Epoch 10, Batch 364 -Loss:   265.5283 Validation Accuracy: 0.867188
# Epoch 10, Batch 365 -Loss:   230.5296 Validation Accuracy: 0.863281
# Epoch 10, Batch 366 -Loss:   165.5643 Validation Accuracy: 0.867188
# Epoch 10, Batch 367 -Loss:   183.0385 Validation Accuracy: 0.863281
# Epoch 10, Batch 368 -Loss:   160.8542 Validation Accuracy: 0.871094
# Epoch 10, Batch 369 -Loss:   312.2989 Validation Accuracy: 0.871094
# Epoch 10, Batch 370 -Loss:   227.0158 Validation Accuracy: 0.871094
# Epoch 10, Batch 371 -Loss:   185.4454 Validation Accuracy: 0.867188
# Epoch 10, Batch 372 -Loss:   158.8601 Validation Accuracy: 0.867188
# Epoch 10, Batch 373 -Loss:   213.5589 Validation Accuracy: 0.863281
# Epoch 10, Batch 374 -Loss:   153.3203 Validation Accuracy: 0.863281
# Epoch 10, Batch 375 -Loss:   251.7061 Validation Accuracy: 0.867188
# Epoch 10, Batch 376 -Loss:   248.4915 Validation Accuracy: 0.863281
# Epoch 10, Batch 377 -Loss:   267.1592 Validation Accuracy: 0.867188
# Epoch 10, Batch 378 -Loss:   195.9633 Validation Accuracy: 0.863281
# Epoch 10, Batch 379 -Loss:   318.0041 Validation Accuracy: 0.867188
# Epoch 10, Batch 380 -Loss:   164.6724 Validation Accuracy: 0.863281
# Epoch 10, Batch 381 -Loss:   389.3574 Validation Accuracy: 0.867188
# Epoch 10, Batch 382 -Loss:   260.6892 Validation Accuracy: 0.867188
# Epoch 10, Batch 383 -Loss:   294.8683 Validation Accuracy: 0.863281
# Epoch 10, Batch 384 -Loss:   243.1040 Validation Accuracy: 0.863281
# Epoch 10, Batch 385 -Loss:   118.7390 Validation Accuracy: 0.863281
# Epoch 10, Batch 386 -Loss:   273.0723 Validation Accuracy: 0.863281
# Epoch 10, Batch 387 -Loss:   223.6779 Validation Accuracy: 0.863281
# Epoch 10, Batch 388 -Loss:   282.8043 Validation Accuracy: 0.863281
# Epoch 10, Batch 389 -Loss:   355.8827 Validation Accuracy: 0.863281
# Epoch 10, Batch 390 -Loss:   247.2706 Validation Accuracy: 0.863281
# Epoch 10, Batch 391 -Loss:   290.8667 Validation Accuracy: 0.863281
# Epoch 10, Batch 392 -Loss:   237.6354 Validation Accuracy: 0.863281
# Epoch 10, Batch 393 -Loss:   137.1225 Validation Accuracy: 0.863281
# Epoch 10, Batch 394 -Loss:   169.2863 Validation Accuracy: 0.863281
# Epoch 10, Batch 395 -Loss:   204.6057 Validation Accuracy: 0.863281
# Epoch 10, Batch 396 -Loss:   174.0120 Validation Accuracy: 0.863281
# Epoch 10, Batch 397 -Loss:   175.6894 Validation Accuracy: 0.863281
# Epoch 10, Batch 398 -Loss:   202.7724 Validation Accuracy: 0.863281
# Epoch 10, Batch 399 -Loss:   273.4904 Validation Accuracy: 0.863281
# Epoch 10, Batch 400 -Loss:   256.2558 Validation Accuracy: 0.863281
# Epoch 10, Batch 401 -Loss:   243.4388 Validation Accuracy: 0.859375
# Epoch 10, Batch 402 -Loss:   280.2691 Validation Accuracy: 0.859375
# Epoch 10, Batch 403 -Loss:   224.6334 Validation Accuracy: 0.859375
# Epoch 10, Batch 404 -Loss:   257.9431 Validation Accuracy: 0.863281
# Epoch 10, Batch 405 -Loss:   169.6660 Validation Accuracy: 0.863281
# Epoch 10, Batch 406 -Loss:   235.5624 Validation Accuracy: 0.859375
# Epoch 10, Batch 407 -Loss:   168.5495 Validation Accuracy: 0.859375
# Epoch 10, Batch 408 -Loss:   219.4095 Validation Accuracy: 0.863281
# Epoch 10, Batch 409 -Loss:   340.4704 Validation Accuracy: 0.863281
# Epoch 10, Batch 410 -Loss:   133.1378 Validation Accuracy: 0.863281
# Epoch 10, Batch 411 -Loss:   242.7676 Validation Accuracy: 0.863281
# Epoch 10, Batch 412 -Loss:   119.4040 Validation Accuracy: 0.863281
# Epoch 10, Batch 413 -Loss:   202.0663 Validation Accuracy: 0.859375
# Epoch 10, Batch 414 -Loss:   366.4724 Validation Accuracy: 0.867188
# Epoch 10, Batch 415 -Loss:   276.7056 Validation Accuracy: 0.863281
# Epoch 10, Batch 416 -Loss:   203.0298 Validation Accuracy: 0.863281
# Epoch 10, Batch 417 -Loss:   212.5576 Validation Accuracy: 0.863281
# Epoch 10, Batch 418 -Loss:   244.0147 Validation Accuracy: 0.871094
# Epoch 10, Batch 419 -Loss:   262.2562 Validation Accuracy: 0.863281
# Epoch 10, Batch 420 -Loss:   336.7107 Validation Accuracy: 0.871094
# Epoch 10, Batch 421 -Loss:   202.0498 Validation Accuracy: 0.871094
# Epoch 10, Batch 422 -Loss:   223.5294 Validation Accuracy: 0.863281
# Epoch 10, Batch 423 -Loss:   140.8141 Validation Accuracy: 0.867188
# Epoch 10, Batch 424 -Loss:   240.8326 Validation Accuracy: 0.867188
# Epoch 10, Batch 425 -Loss:   185.0430 Validation Accuracy: 0.867188
# Epoch 10, Batch 426 -Loss:   137.8089 Validation Accuracy: 0.871094
# Epoch 10, Batch 427 -Loss:   303.0037 Validation Accuracy: 0.871094
# Epoch 10, Batch 428 -Loss:   283.1882 Validation Accuracy: 0.863281
# Epoch 10, Batch 429 -Loss:   126.4563 Validation Accuracy: 0.863281
# Testing Accuracy: 0.87109375

# %% [markdown]
# # Quiz: TensorFlow Convolution Layer
# ## My Solution

# %%
"""
Setup the strides, padding and filter weight/bias such that
the output shape is (1, 2, 2, 3).
"""
import tensorflow as tf
import numpy as np

# `tf.nn.conv2d` requires the input be 4D (batch_size, height, width, depth)
# (1, 4, 4, 1)
x = np.array([
    [0, 1, 0.5, 10],
    [2, 2.5, 1, -8],
    [4, 0, 5, 6],
    [15, 1, 2, 3]], dtype=np.float32).reshape((1, 4, 4, 1))
X = tf.constant(x)


def conv2d(input):
    # Filter (weights and bias)
    # The shape of the filter weight is (height, width, input_depth, output_depth)
    # The shape of the filter bias is (output_depth,)
    # TODO: Define the filter weights `F_W` and filter bias `F_b`.
    # NOTE: Remember to wrap them in `tf.Variable`, they are trainable parameters after all.
    F_W = tf.Variable(tf.truncated_normal([4, 4, 1, 3]))
    F_b = tf.Variable(tf.truncated_normal([3]))
    # TODO: Set the stride for each dimension (batch_size, height, width, depth)
    strides = [1, 2, 2, 1]
    # TODO: set the padding, either 'VALID' or 'SAME'.
    padding = 'SAME'
    # https://www.tensorflow.org/versions/r0.11/api_docs/python/nn.html#conv2d
    # `tf.nn.conv2d` does not include the bias computation so we have to add it ourselves after.
    return tf.nn.conv2d(input, F_W, strides, padding) + F_b

out = conv2d(X)

# %% [markdown]
# ## Their Solution

# %%
def conv2d(input):
    # Filter (weights and bias)
    F_W = tf.Variable(tf.truncated_normal((2, 2, 1, 3)))
    F_b = tf.Variable(tf.zeros(3))
    strides = [1, 2, 2, 1]
    padding = 'VALID'
    return tf.nn.conv2d(input, F_W, strides, padding) + F_b

# %% [markdown]
# I want to transform the input shape (1, 4, 4, 1) to (1, 2, 2, 3). I choose 'VALID' for the padding algorithm. I find it simpler to understand and it achieves the result I'm looking for.
# ```python
# out_height = ceil(float(in_height - filter_height + 1) / float(strides[1]))
# out_width  = ceil(float(in_width - filter_width + 1) / float(strides[2]))
# ```
#
# Plugging in the values:
#
# ```python
# out_height = ceil(float(4 - 2 + 1) / float(2)) = ceil(1.5) = 2
# out_width  = ceil(float(4 - 2 + 1) / float(2)) = ceil(1.5) = 2
# ```

# %%
import math
math.ceil(float(10 - 2 + 1) / float(2))
# Out:
# 5
